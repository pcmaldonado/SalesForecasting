# %% [markdown]
# # Libraries

# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# Regression algorithms
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (RandomForestRegressor, ExtraTreesRegressor, 
                              AdaBoostRegressor, GradientBoostingRegressor)
from xgboost import XGBRegressor


# Fine tuning models
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import TimeSeriesSplit


# Metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


# Import
import pickle

# %% [markdown]
# # Data

# %%
df = pd.read_csv('sales_store_train_data.csv', index_col = 'Date', parse_dates = True)
df = df.drop(['Customers'], axis = 1)

# %%
# Separate target & features
y_train = np.log(df.Sales)

X_train = df.drop(['Sales'], axis = 1)
feat_names = X_train.columns

# %%
print(df.shape)
df.head()
# Out:
# (804056, 26)
#             DayOfWeek  Sales  Promo  StateHoliday  SchoolHoliday  Year  Month  \
# Date
# 2015-06-19          5   7329      1             0              0  2015      6
# 2015-06-19          5   9367      1             0              0  2015      6
# 2015-06-19          5   7856      1             0              0  2015      6
# 2015-06-19          5   8074      1             0              0  2015      6
# 2015-06-19          5   8626      1             0              0  2015      6
#
#             Week  Day  StoreType  ...  Assortment_basic  Assortment_extended  \
# Date                              ...
# 2015-06-19    25   19        348  ...                 0                    1
# 2015-06-19    25   19        148  ...                 0                    1
# 2015-06-19    25   19        348  ...                 0                    1
# 2015-06-19    25   19        602  ...                 1                    0
# 2015-06-19    25   19        602  ...                 1                    0
#
#             Assortment_extra  PromoInterval_0  PromoInterval_Jan,Apr,Jul,Oct  \
# Date
# 2015-06-19                 0                1                              0
# 2015-06-19                 0                1                              0
# 2015-06-19                 0                0                              0
# 2015-06-19                 0                0                              1
# 2015-06-19                 0                0                              1
#
#             PromoInterval_Feb,May,Aug,Nov  PromoInterval_Mar,Jun,Sept,Dec  \
# Date
# 2015-06-19                              0                               0
# 2015-06-19                              0                               0
# 2015-06-19                              0                               1
# 2015-06-19                              0                               0
# 2015-06-19                              0                               0
#
#             StateGDP  StateDensity  AvgWeaklyCusts
# Date
# 2015-06-19     70755          1743        6.604942
# 2015-06-19     22427           116        6.604942
# 2015-06-19     37509           287        6.604942
# 2015-06-19     22980           227        6.604942
# 2015-06-19     35443           178        6.604942
#
# [5 rows x 26 columns]

# %% [markdown]
# # Model

# %%
metrics = ['neg_root_mean_squared_error','neg_mean_absolute_error', 'r2']

# %%
models = []
scores = []

# %%
tscv = TimeSeriesSplit(n_splits=3)

# %%
# %%time
classes = [DecisionTreeRegressor(random_state = 42),
              ExtraTreesRegressor(random_state = 42, n_estimators = 30),
              RandomForestRegressor(random_state = 42, n_estimators = 30),
              AdaBoostRegressor(random_state = 42, n_estimators = 30),
              GradientBoostingRegressor(random_state = 42, n_estimators = 30),
              XGBRegressor(random_state = 42, n_estimators = 30)
          ]


for model in classes:
    model.fit(X_train, y_train)
    
    cross_val = cross_validate(model, X_train, y_train, 
                               cv = tscv, scoring = metrics)

    models.append(f'{model.__class__.__name__}')
    scores.append(list(cross_val.values())[2:])
# Out:
# Wall time: 15min 44s

# %%
data = []
for i in range(len(models)):
    for j in range(len(metrics)):
        data.append(scores[i][j].mean())

data = np.reshape(data, (len(models), len(metrics)))
        
df_models = pd.DataFrame(data, index = models, columns = metrics)
df_models.style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_dfd65_row2_col0,#T_dfd65_row2_col1,#T_dfd65_row2_col2{
#             background-color:  lightgreen;
#         }</style><table id="T_dfd65_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neg_root_mean_squared_error</th>        <th class="col_heading level0 col1" >neg_mean_absolute_error</th>        <th class="col_heading level0 col2" >r2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfd65_level0_row0" class="row_heading level0 row0" >DecisionTreeRegressor</th>
#                         <td id="T_dfd65_row0_col0" class="data row0 col0" >-0.196637</td>
#                         <td id="T_dfd65_row0_col1" class="data row0 col1" >-0.139703</td>
#                         <td id="T_dfd65_row0_col2" class="data row0 col2" >0.787191</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd65_level0_row1" class="row_heading level0 row1" >ExtraTreesRegressor</th>
#                         <td id="T_dfd65_row1_col0" class="data row1 col0" >-0.161755</td>
#                         <td id="T_dfd65_row1_col1" class="data row1 col1" >-0.116366</td>
#                         <td id="T_dfd65_row1_col2" class="data row1 col2" >0.855950</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd65_level0_row2" class="row_heading level0 row2" >RandomForestRegressor</th>
#                         <td id="T_dfd65_row2_col0" class="data row2 col0" >-0.160510</td>
#                         <td id="T_dfd65_row2_col1" class="data row2 col1" >-0.115650</td>
#                         <td id="T_dfd65_row2_col2" class="data row2 col2" >0.858101</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd65_level0_row3" class="row_heading level0 row3" >AdaBoostRegressor</th>
#                         <td id="T_dfd65_row3_col0" class="data row3 col0" >-0.377376</td>
#                         <td id="T_dfd65_row3_col1" class="data row3 col1" >-0.294779</td>
#                         <td id="T_dfd65_row3_col2" class="data row3 col2" >0.216255</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd65_level0_row4" class="row_heading level0 row4" >GradientBoostingRegressor</th>
#                         <td id="T_dfd65_row4_col0" class="data row4 col0" >-0.357710</td>
#                         <td id="T_dfd65_row4_col1" class="data row4 col1" >-0.277907</td>
#                         <td id="T_dfd65_row4_col2" class="data row4 col2" >0.295693</td>
#             </tr>
#             <tr>
#                         <th id="T_dfd65_level0_row5" class="row_heading level0 row5" >XGBRegressor</th>
#                         <td id="T_dfd65_row5_col0" class="data row5 col0" >-0.259303</td>
#                         <td id="T_dfd65_row5_col1" class="data row5 col1" >-0.200037</td>
#                         <td id="T_dfd65_row5_col2" class="data row5 col2" >0.629753</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Fine Tune

# %%
fine_tuned_models = []
new_models = []
new_scores = []

# %%
# %%time

'''RandomForestRegressor
parameters: 
    n_estimators: number of trees in the forest; (default = 100)
                    generally random forests do not overfit as more trees are added, however, the increase on
                    performance does not necessarily justifies the increase on complexity (more time/resources)
                    
    max_depth: maximum depth of each tree in the forest; (default = None, all leaves are expanded as much as possible)
                    generally, the deeper the tree, the more splits, which can lead to higher performance, as it
                    allows the model to better fit the data (lower bias), however this can also lead to higher
                    variance as the model can start to overfit the training data
    
    min_samples_split: minimum number of samples required to split an internal node; (default = 2)
                    this can reduce the number of splits, which can reduce overfitting, however, if too large, it
                    can also lead to underfitting the training set
    
    min_samples_leaf: mininum number of samples that must be present in a leaf/terminal node (end of the tree); (default = 1)
                    as before, a higher value can reduce overfitting but a too high value can lead to underfitting.
                    Specially in regression, a higher value can also smooth the model, by avoiding leaves with only one value
                    
    max_features: number of features to consider for best split (deafault = 'auto', total number of features)
                    a higher number will lead to better performance, but a too high number will also lead to overfitting.
                    Moreover, the higher the number, the more computationally expensive the model becomes.
    
    max_samples: number (or %) of samples to draw from X to train each base estimator (default = None, total num of samples)
                     The lower the value, the more randomness is introduced to the data.
                     --Only possible if Bootstrap = True.
    '''

param_grid = {'max_depth':[32, 40, 48],
              'min_samples_split':[2, 3, 4],
              'min_samples_leaf':[1, 2, 3],
              'max_features':[16, 20, 24],
              'max_samples':[0.8, 0.9, 1.0]
             }

rf_gd = GridSearchCV(estimator=RandomForestRegressor(n_estimators=50, 
                                                       random_state=42, 
                                                       bootstrap=True,
                                                       n_jobs=-1),
                      param_grid=param_grid, 
                      cv=tscv, 
                      scoring=metrics,
                      refit='neg_mean_absolute_error',
                      error_score='raise', 
                      verbose=2)
                     
rf_gd.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   7.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  14.3s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  23.2s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   5.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  13.7s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  22.1s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   5.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  12.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  21.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   5.1s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  13.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  20.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   5.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  13.3s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  21.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   5.3s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  14.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  22.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   4.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  11.7s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  21.3s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   4.6s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  11.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  21.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   5.1s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  12.6s
# [CV] END max_depth=32, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  20.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   6.2s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  16.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  25.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   5.6s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  14.6s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  24.6s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   5.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  13.2s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  23.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   5.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  13.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  22.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   5.2s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  13.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  23.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   5.1s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  12.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  21.5s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   4.7s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  12.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  21.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   4.9s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  12.4s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  22.1s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   4.8s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  13.0s
# [CV] END max_depth=32, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  21.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   6.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  16.0s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  27.3s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   6.3s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  14.9s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  24.3s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   5.6s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  14.2s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  23.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  14.7s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  24.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   5.6s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  14.2s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  23.9s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   5.6s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  14.2s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  24.0s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   5.2s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  13.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  23.4s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   5.3s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  13.9s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  25.3s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   5.7s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  13.9s
# [CV] END max_depth=32, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  23.2s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   6.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  16.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  29.4s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   6.4s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  15.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  26.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   6.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  14.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  25.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   5.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  14.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  25.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   5.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  14.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  25.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   7.4s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  15.4s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  24.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  13.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  23.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   5.2s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  13.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  23.7s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   5.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  13.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  23.7s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   7.0s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  17.0s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  28.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   6.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  15.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  27.8s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  15.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  27.7s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   5.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  15.1s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  26.0s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   6.2s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  15.2s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  26.1s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   6.0s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  15.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  26.9s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   5.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  14.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  25.7s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   5.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  14.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  25.3s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   5.5s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  14.6s
# [CV] END max_depth=32, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  25.5s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   7.3s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  18.0s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  30.6s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   6.7s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  16.8s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  29.3s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  16.2s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  28.5s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   6.4s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  16.0s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  27.8s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   6.3s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  16.2s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  27.9s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  16.4s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  28.6s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   6.2s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  15.7s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  26.9s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   6.0s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  15.4s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  27.1s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   5.8s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  15.5s
# [CV] END max_depth=32, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  26.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   7.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  18.2s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  31.8s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   6.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  17.1s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  30.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   6.6s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  16.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  29.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   6.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  16.2s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  28.8s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   6.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  16.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  28.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  16.2s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  29.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   6.1s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  15.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  28.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   6.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  15.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  28.8s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   7.1s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  17.7s
# [CV] END max_depth=32, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  28.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   8.2s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  20.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  35.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   8.1s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  18.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  32.7s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   7.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  17.7s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  31.8s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   6.8s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  17.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  31.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   7.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  17.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  31.2s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   7.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  17.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  31.3s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   7.0s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  16.6s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  30.1s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   6.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  16.9s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  30.5s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  16.7s
# [CV] END max_depth=32, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  30.2s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   8.5s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  21.0s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  37.6s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   7.9s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  19.5s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  34.3s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   7.5s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  18.8s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  33.6s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   7.3s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  18.4s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  33.6s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   7.4s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  18.5s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  33.0s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   7.4s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  18.6s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  33.0s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   6.9s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  17.9s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  31.8s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   6.8s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  18.1s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  31.9s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   6.8s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  18.9s
# [CV] END max_depth=32, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  32.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   5.5s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  13.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  22.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   5.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  12.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  21.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   5.0s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  12.5s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  21.2s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   4.8s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  11.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  20.2s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   4.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  11.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  20.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   4.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  12.0s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  20.2s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   4.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  11.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  19.3s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   4.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  11.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  19.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   4.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  11.3s
# [CV] END max_depth=40, max_features=16, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  19.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   5.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  14.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  24.3s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   5.8s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  13.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  22.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   5.3s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  13.4s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  21.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   5.0s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  12.8s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  21.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   5.0s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  12.9s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  24.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   5.2s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  13.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  24.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   5.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  13.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  23.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   5.7s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  15.5s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  26.5s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   5.6s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  15.1s
# [CV] END max_depth=40, max_features=16, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  24.4s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   7.4s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  18.1s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  31.7s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   6.9s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  17.4s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  27.4s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   6.2s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  15.8s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  25.3s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   5.9s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  16.2s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  23.7s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   5.3s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  13.8s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  24.9s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   5.9s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  15.6s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  24.8s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   5.0s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  13.1s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  23.8s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   5.7s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  14.1s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  24.2s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   5.2s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  13.5s
# [CV] END max_depth=40, max_features=16, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  23.8s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   6.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  16.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  28.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   6.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  16.5s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  27.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   6.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  17.0s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  28.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   6.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  15.2s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  27.7s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   5.8s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  15.3s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  26.7s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   5.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  14.5s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  26.8s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  14.2s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  28.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   5.5s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  14.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  26.8s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   5.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  14.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  27.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   7.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  18.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  31.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   7.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  17.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  32.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   6.5s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  18.0s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  31.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   6.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  18.0s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  33.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   7.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  16.5s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  28.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  17.0s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  29.2s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   6.0s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  15.4s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  27.1s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   5.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  15.6s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  26.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   5.8s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  14.9s
# [CV] END max_depth=40, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  26.5s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   7.7s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  19.9s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  32.2s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   7.0s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  17.8s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  29.0s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  16.6s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  28.6s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   6.2s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  16.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  28.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   6.3s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  16.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  28.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   6.3s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  16.0s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  28.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   6.5s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  17.8s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  28.5s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   6.1s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  16.7s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  30.7s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   7.2s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  16.9s
# [CV] END max_depth=40, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  30.4s
# [CV] END max_depth=40, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   8.2s
# [CV] END max_depth=40, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  20.3s
# [CV] END max_depth=40, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  36.2s
# [CV] END max_depth=40, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   7.5s
# ...
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  30.9s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   7.0s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  17.9s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  31.3s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   6.7s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  17.1s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  29.6s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   6.4s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  16.9s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  28.6s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   6.5s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  17.5s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  28.8s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   6.1s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  15.9s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  27.8s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   6.2s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  15.8s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  28.4s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   6.1s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  16.4s
# [CV] END max_depth=48, max_features=20, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  29.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   8.9s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  21.2s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  36.2s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   8.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  20.8s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  33.6s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   7.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  18.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  31.8s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   7.1s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  17.2s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  30.0s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   7.1s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  17.5s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  30.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   7.0s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  17.7s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  30.0s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   6.4s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  16.8s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  29.3s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   6.6s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  17.0s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  29.9s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   6.4s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  17.1s
# [CV] END max_depth=48, max_features=20, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  29.3s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=   8.1s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  19.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=2; total time=  32.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  18.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=3; total time=  31.5s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=   6.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  17.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=1, min_samples_split=4; total time=  30.3s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=   6.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  16.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=2; total time=  35.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  19.5s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=3; total time=  34.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  18.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=2, min_samples_split=4; total time=  32.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=   6.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  17.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=2; total time=  30.8s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=   6.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  17.3s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=3; total time=  30.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=   6.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  16.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.8, min_samples_leaf=3, min_samples_split=4; total time=  30.5s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=   8.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  21.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=2; total time=  40.1s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=   8.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  20.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=3; total time=  36.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=   8.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  21.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=1, min_samples_split=4; total time=  35.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=   7.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  19.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=2; total time=  33.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=   7.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  19.1s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=3; total time=  35.4s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=   7.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  20.8s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=2, min_samples_split=4; total time=  35.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=   6.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  18.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=2; total time=  33.8s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  18.6s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=3; total time=  33.7s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=   6.9s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  18.0s
# [CV] END max_depth=48, max_features=24, max_samples=0.9, min_samples_leaf=3, min_samples_split=4; total time=  33.7s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=   9.3s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  23.4s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=2; total time=  41.1s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=   9.0s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  22.7s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=3; total time=  38.4s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=   8.5s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  21.3s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=1, min_samples_split=4; total time=  39.6s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=   8.3s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  20.0s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=2; total time=  33.8s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  18.4s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=3; total time=  33.3s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=   7.2s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  18.8s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=2, min_samples_split=4; total time=  34.2s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=   7.1s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  17.9s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=2; total time=  32.0s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=   6.7s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  17.7s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=3; total time=  32.1s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=   6.9s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  17.6s
# [CV] END max_depth=48, max_features=24, max_samples=1.0, min_samples_leaf=3, min_samples_split=4; total time=  32.3s
# Wall time: 3h 31min 56s
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              error_score='raise',
#              estimator=RandomForestRegressor(n_estimators=50, n_jobs=-1,
#                                              random_state=42),
#              param_grid={'max_depth': [32, 40, 48],
#                          'max_features': [16, 20, 24],
#                          'max_samples': [0.8, 0.9, 1.0],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4]},
#              refit='neg_mean_absolute_error',
#              scoring=['neg_root_mean_squared_error', 'neg_mean_absolute_error',
#                       'r2'],
#              verbose=2)

# %%
import pickle 
filename = 'RFRegressor.pkl'
pickle.dump(rf_gd.best_estimator_, open(filename, 'wb'))

# %%
fine_tuned_models.append(rf_gd.best_estimator_)
rf_gd.best_params_
# Out:
# {'max_depth': 48,
#  'max_features': 24,
#  'max_samples': 0.8,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3}

# %% [markdown]
# ### XGB Regressor

# %%
# %%time
# https://xgboost.readthedocs.io/en/stable/python/python_api.html?highlight=xgboost%20xgbregressor#xgboost.XGBRegressor
'''XGBRegressor
parameters: 
    n_estimators: number of gradient boosted trees;
                    
    max_depth: maximum depth of each tree; (default = 6)
                    a higher value leads to a more complex model, more likely to overfit.
    
    learning_rate: boosting learning rate; (default = 0.3)
                    it shrinks the feature weights to make the boosting process more conservative. It prevents overfitting.
    
    subsample: subsample ratio if the training instances; (default = 1)
                    a lower value can help prevent overfitting.
   
    colsample_bytree: subsample ratio of columns (features) when constructing each tree; (default = 1)
                    similar to max_features in RandomForest/ExtraTrees
                    
    reg_alpha: L1 regularization term on weights; (default = 1)
                    increasing this value can prevent overfitting
                    
    reg_lambda: L2 regularization term on weights; (default = 0)
                    increasing this value can prevent overfitting
    '''

param_grid = {'max_depth':[20, 24],
              'learning_rate':[0.06, 0.08],
              'subsample':[0.8, 0.9],
              'colsample_bytree':[0.7, 0.8],
              'reg_alpha':[1.0, 1.3],
              'reg_lambda':[0.5, 0.8]}

xgb_gd = GridSearchCV(estimator = XGBRegressor(n_estimators = 50, random_state = 42, n_jobs = -1),
                      param_grid = param_grid, 
                      cv = tscv, 
                      scoring = metrics,
                      refit = 'neg_root_mean_squared_error',
                      error_score = 'raise', 
                      verbose = 2)
                     
xgb_gd.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  13.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  24.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  14.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  23.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  20.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  12.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  20.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  19.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   5.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  12.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  22.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  12.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  20.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   5.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  12.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  20.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  13.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  22.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  22.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  13.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  22.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  22.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  14.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  22.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  22.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  12.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  21.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  14.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  23.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  13.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  23.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  13.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  21.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  14.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  22.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  13.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  21.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   6.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  13.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  21.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  13.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  24.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  13.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  21.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  28.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  16.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  25.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  26.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   7.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  15.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  24.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  14.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  22.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  14.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  24.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  14.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  22.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   6.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  14.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  22.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  13.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  23.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  22.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  21.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  23.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  22.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  14.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  21.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  22.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  12.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  21.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  24.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  14.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  25.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  23.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  14.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  24.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  23.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  23.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  13.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  23.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  13.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  24.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  23.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  15.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  28.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  24.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  14.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  23.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  23.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  24.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  13.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  23.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=20, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  22.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  15.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  15.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.5, subsample=0.9; total time=  26.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  15.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.8; total time=  25.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  16.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.0, reg_lambda=0.8, subsample=0.9; total time=  26.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.8; total time=  26.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  15.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.5, subsample=0.9; total time=  25.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.08, max_depth=24, reg_alpha=1.3, reg_lambda=0.8, subsample=0.9; total time=  25.2s
# Wall time: 47min 49s
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              error_score='raise',
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta...
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              param_grid={'colsample_bytree': [0.7, 0.8],
#                          'learning_rate': [0.06, 0.08], 'max_depth': [20, 24],
#                          'reg_alpha': [1.0, 1.3], 'reg_lambda': [0.5, 0.8],
#                          'subsample': [0.8, 0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['neg_root_mean_squared_error', 'neg_mean_absolute_error',
#                       'r2'],
#              verbose=2)

# %%
filename = 'XGBRegressor.pkl'
pickle.dump(xgb_gd.best_estimator_, open(filename, 'wb'))

# %%
fine_tuned_models.append(xgb_gd.best_estimator_)
xgb_gd.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.08,
#  'max_depth': 24,
#  'reg_alpha': 1.0,
#  'reg_lambda': 0.5,
#  'subsample': 0.9}

# %% [markdown]
# ## Comparing models

# %%
# %%time
for model in fine_tuned_models:
    cross_val = cross_validate(model, X_train, y_train, cv= tscv, scoring = metrics)

    new_models.append(f'{model.__class__.__name__}')
    new_scores.append(list(cross_val.values())[2:])
    print('')

data = []
for model in range(len(fine_tuned_models)):
    for score in range(len(metrics)):
        data.append(new_scores[model][score].mean())

data = np.reshape(data, (len(fine_tuned_models), len(metrics)))
        
df_models = pd.DataFrame(data, index = new_models, columns = metrics)
# Out:
# Wall time: 1min 56s

# %%
df_models.style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_5d2d3_row0_col0,#T_5d2d3_row0_col1,#T_5d2d3_row0_col2{
#             background-color:  lightgreen;
#         }</style><table id="T_5d2d3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neg_root_mean_squared_error</th>        <th class="col_heading level0 col1" >neg_mean_absolute_error</th>        <th class="col_heading level0 col2" >r2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d2d3_level0_row0" class="row_heading level0 row0" >RandomForestRegressor</th>
#                         <td id="T_5d2d3_row0_col0" class="data row0 col0" >-0.157290</td>
#                         <td id="T_5d2d3_row0_col1" class="data row0 col1" >-0.113587</td>
#                         <td id="T_5d2d3_row0_col2" class="data row0 col2" >0.863776</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2d3_level0_row1" class="row_heading level0 row1" >XGBRegressor</th>
#                         <td id="T_5d2d3_row1_col0" class="data row1 col0" >-0.215799</td>
#                         <td id="T_5d2d3_row1_col1" class="data row1 col1" >-0.168316</td>
#                         <td id="T_5d2d3_row1_col2" class="data row1 col2" >0.743698</td>
#             </tr>
#     </tbody></table>
